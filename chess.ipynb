# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img = mpimg.imread('bwcatur.jpeg')
plt.imshow(img)

# %%
criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 30, 0, 0.001)

# %%
objp = np.zeros((6*7,3), np.float32)

# %%
objp[:,:2] = np.mgrid[0:7,0:6].T.reshape(-1,2)

# %%
objpoints = [] # 3d point in real world space
imgpoints = [] # 2d point in image plane

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
ret, corners = cv2.findChessboardCorners(img_gray, (8,6), None)

# %%
if ret == True:
    imgpoints.append(corners)
    objpoints.append(objb)

# %%
if ret == True:
    imgpoints.append(corners)
    objpoints.append(objb)

# %%
img = cv2.drawChessboardCorners(img, (8,6), corners, ret)

# %%
plt.imshow(img)

# %%
cv2.calibrateCamera(objpoints, imgpoints, gray.shape[::-1],None,None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-ef11fa3bbfaf> in <module>
# ----> 1 cv2.calibrateCamera(objpoints, imgpoints, gray.shape[::-1],None,None)
#
# NameError: name 'gray' is not defined
